# %%
from pyspark.sql import functions as F
# Out:
# StatementMeta(, dd4f4aaf-6bee-4dc2-a910-011ec7cd584d, 3, Finished, Available, Finished, False)

# %%
# Read orders from Bronze
orders_df = spark.read.table("LH_Olist_Bronze.olist_orders_dataset")

# Display the Bronze data
display(orders_df)
# Out:
# StatementMeta(, dd4f4aaf-6bee-4dc2-a910-011ec7cd584d, 4, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Read orders from Bronze
# ----> 2 orders_df = spark.read.table("LH_Olist_Bronze.olist_orders_dataset")
#       4 # Display the Bronze data
#       5 display(orders_df)
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/readwriter.py:484, in DataFrameReader.table(self, tableName)
#     450 def table(self, tableName: str) -> "DataFrame":
#     451     """Returns the specified table as a :class:`DataFrame`.
#     452
#     453     .. versionadded:: 1.4.0
#    (...)
#     482     >>> _ = spark.sql("DROP TABLE tblA")
#     483     """
# --> 484     return self._df(self._jreader.table(tableName))
#
# ...

# %%
spark.read.table("LH_Olist_Bronze.olist_orders_dataset")
# Out:
# StatementMeta(, dd4f4aaf-6bee-4dc2-a910-011ec7cd584d, 5, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 spark.read.table("LH_Olist_Bronze.olist_orders_dataset")
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/readwriter.py:484, in DataFrameReader.table(self, tableName)
#     450 def table(self, tableName: str) -> "DataFrame":
#     451     """Returns the specified table as a :class:`DataFrame`.
#     452
#     453     .. versionadded:: 1.4.0
#    (...)
#     482     >>> _ = spark.sql("DROP TABLE tblA")
#     483     """
# --> 484     return self._df(self._jreader.table(tableName))
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %%
orders_df.printSchema()
# Out:
# StatementMeta(, dd4f4aaf-6bee-4dc2-a910-011ec7cd584d, 6, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 orders_df.printSchema()
#
# NameError: name 'orders_df' is not defined

# %%
display(mssparkutils.fs.ls("Files"))
# Out:
# StatementMeta(, dd4f4aaf-6bee-4dc2-a910-011ec7cd584d, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 965a998b-66b9-4a65-8aff-ce5f758b34e2)

# %%
display(mssparkutils.fs.ls("Files"))
# Out:
# StatementMeta(, dd4f4aaf-6bee-4dc2-a910-011ec7cd584d, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ffdfca41-fe72-4a7e-a451-1c6105ec3dc9)
